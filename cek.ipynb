# %% [markdown]
# ## City Mapping

# %%
import re
import psycopg2
from sqlalchemy import create_engine,inspect,sql

DATABASE_URL = 'postgresql+psycopg2://honeybee:01943a32-f818-4996-aa8a-31df792af1c5@35.232.206.25/honeybee_warehouse'
ENGINE = create_engine(DATABASE_URL)
CONN = ENGINE.connect()


def getMappingRegencies():
    ## query to get data from mapping_product table based on product_name, shop_domain, and platform
    query = sql.text("""SELECT * from regencies""")  
    result_query = CONN.execute(query).fetchall()
    db_mapping_regencies = [{'id':v['id'], 'province_id':v['province_id'], 'name':v['name']} for v in result_query]
    return db_mapping_regencies

# %%
def findWholeWord(w):
    return re.compile(r'\b({0})\b'.format(w), flags=re.IGNORECASE).search

# %%
db_mapping_regencies = getMappingRegencies()

# %%
regx_replace = ['KOTA ','KAB ','KABUPATEN ','.']
multi_sep = "_| _ |-| - |;|,|\n"


a = 'JL. Muara Karang Raya No. 30, Pluit - kota Jakarta Utara'.upper()
regency = re.split(multi_sep,a)[-1]

for r in regx_replace:
    regency = regency.replace(r,'')


for mr in db_mapping_regencies:
    if findWholeWord(regency)(mr['name']):
        print(mr['id'])
# Out:
# 3175

# %%
regency
# Out:
# 'JAKARTA UTARA'

# %%
import requests
import json

api = 'https://us-central1-commercesense-prod.cloudfunctions.net/get_store_crawl?platform={platform}&type={crawl_type}&token=e288271e7afa6f9618d2ac558fa8021faea0b9d063ba04a685a628395f1cf15e'

list_item = json.loads(requests.get(api.format(platform='Tokopedia', crawl_type ='atp')).text)['data']
list_item = list(filter(lambda x: x['store_category'] == 'Mom & Baby', list_item))
list_item
# Out:
# [{'crawling_type': 'atp',
#   'cron': '* * * * *',
#   'dev_email': 'fatih.dq19spam@gmail.com',
#   'filter': 'tjsmart',
#   'max_page': 1,
#   'max_product': 80,
#   'page_batch': 1,
#   'params': None,
#   'pic_email': 'lixus.dataflow.notification@gmail.com',
#   'platform': 'Tokopedia',
#   'product_batch': 10,
#   'referer': 'https://www.tokopedia.com/tjsmart',
#   'store_category': 'Mom & Baby'},
#  {'crawling_type': 'atp',
#   'cron': '* * * * *',
#   'dev_email': 'tarangga.arief@gmail.com',
#   'filter': 'rajasusu',
#   'max_page': 10,
#   'max_product': 80,
#   'page_batch': 2,
#   'params': None,
#   'pic_email': 'lixus.dataflow.notification@gmail.com',
#   'platform': 'Tokopedia',
#   'product_batch': 40,
#   'referer': 'https://www.tokopedia.com/rajasusu',
#   'store_category': 'Mom & Baby'},
#  {'crawling_type': 'atp',
#   'cron': '* * * * *',
#   'dev_email': 'fatih.dq19spam@gmail.com',
#   'filter': 'makmuronline',
#   'max_page': 4,
#   'max_product': 80,
# ...

# %%
python3 ./dataflow/_crawl_atp_tokopedia_main.py \
        --runner DataflowRunner \
        --project commercesense-prod \
        --staging_location gs://seller_scraping/dataflow_staging \
        --temp_location gs://seller_scraping/dataflow_temp \
        --template_location gs://seller_scraping/dataflow_template/transform_atp_tokopedia_v2 \
        --requirements_file ./dataflow/requirements.txt \
        --setup_file ./dataflow/setup.py \
        --region us-central
# Out:
# /usr/local/bin/python3: Error while finding module specification for '_crawl_atp_tokopedia_main.py' (ModuleNotFoundError: No module named '_crawl_atp_tokopedia_main'). Try using '_crawl_atp_tokopedia_main' instead of '_crawl_atp_tokopedia_main.py' as the module name.

# %%
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, product_id, product_name, product_url, sku, price, stock, date, shop_name, shop_lixus, platform, shop_category]
# Index: []

# %%
list_date = ['2023-04-28','2023-05-30','2023-06-28']

first_date = '2023-06-01'
last_date = '2023-06-30'

for d in list_date:
    if d >= first_date and d<=list_date:
        print(True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Applications/Folder/Work/repository/honeybee-etl/transformation/local/cek.ipynb Cell 10 in <module>
#       <a href='vscode-notebook-cell:/Applications/Folder/Work/repository/honeybee-etl/transformation/local/cek.ipynb#X12sZmlsZQ%3D%3D?line=3'>4</a> last_date = '2023-06-30'
#       <a href='vscode-notebook-cell:/Applications/Folder/Work/repository/honeybee-etl/transformation/local/cek.ipynb#X12sZmlsZQ%3D%3D?line=5'>6</a> for d in list_date:
# ----> <a href='vscode-notebook-cell:/Applications/Folder/Work/repository/honeybee-etl/transformation/local/cek.ipynb#X12sZmlsZQ%3D%3D?line=6'>7</a>     if d >= first_date and d<=list_date:
#       <a href='vscode-notebook-cell:/Applications/Folder/Work/repository/honeybee-etl/transformation/local/cek.ipynb#X12sZmlsZQ%3D%3D?line=7'>8</a>         print(True)
#
# ...

# %%
# !gcloud builds submit --config deploy.yaml

# %%
import pandas as pd
import numpy as np

## TO DO: Sample Data
df = pd.DataFrame.from_dict([{'user_id':'a','hastag_label':np.nan},
                             {'user_id':'b','hastag_label':np.nan},
                             {'user_id':'c','hastag_label':['geloratalks','geloratv']},
                             {'user_id':'d','hastag_label':np.nan},
                             {'user_id':'e','hastag_label':['geloratalks','geloratv']},
                             {'user_id':'f','hastag_label':['geloratalks','geloratv']}])

## TO DO: Print Sample Data
print("sebelum split hastag_label:")
print(df)
print()

## TO DO:
## 1. Itterate every row end check it up if data type is list
## 2. append idx that will be drop -> drop_idx
## 3. create new dataframe that include user id and hastag_label -> new_df
new_df = pd.DataFrame()
drop_idx = []

for idx, row in df.iterrows():
    if type(row['hastag_label'])==list:
        drop_idx.append(idx)
        for val in row['hastag_label']:
            new_df = pd.concat([new_df,
                                 pd.DataFrame.from_dict([{'user_id':row['user_id'],'hastag_label':val}])])

## TO DO:
## 1. drop dataframe with list idx
## 2. concat dataframe with new Dataframe
df = df.drop(drop_idx).reset_index(drop=True)
df = pd.concat([df, new_df])

print("sesudah split hastag_label:")
print(df)
print()
# Out:
# sebelum split hastag_label:
#   user_id             hastag_label
# 0       a                      NaN
# 1       b                      NaN
# 2       c  [geloratalks, geloratv]
# 3       d                      NaN
# 4       e  [geloratalks, geloratv]
# 5       f  [geloratalks, geloratv]
#
# sesudah split hastag_label:
#   user_id hastag_label
# 0       a          NaN
# 1       b          NaN
# 2       d          NaN
# 0       c  geloratalks
# 0       c     geloratv
# 0       e  geloratalks
# 0       e     geloratv
# 0       f  geloratalks
# 0       f     geloratv

# %%
df
# Out:
#   user_id             hastag_label
# 0       a                      NaN
# 1       b                      NaN
# 2       c  [geloratalks, geloratv]
# 3       d                      NaN
# 4       e  [geloratalks, geloratv]
# 5       f  [geloratalks, geloratv]

# %% [markdown]
# ## Check New Subrand Prediction

# %%
import json
import pandas as pd 
import re

df = pd.read_excel('sample_product2.xlsx')
df = df.rename(columns={'brand':'predicted_brand'})
df.loc[:,'predicted_brand'] = ''
df = df[['product_name','predicted_brand']]
df
# Out:
#                                            product_name predicted_brand
# 0                                   Wafer coklat dancow
# 1                                             sweetener
# 2                                         gula pasir 2g
# 3     [1 KARTON ISI 12] Morinaga  Chilkid Reguler Ma...
# 4     [1 KARTON ISI 12] Morinaga  Chil Kid Soya 600 ...
# ...                                                 ...             ...
# 1648                                   Susu Enfamil A 2
# 1649                                    Susu Enfamil A2
# 1650        Susu Formula Bayi BMT REGULAR / GOLD 400 GR
# 1651       Susu Morinaga Chil Mil 2 400 Gram Rasa Tawar
# 1652  Unable to obtain product information because o...
#
# [1653 rows x 2 columns]

# %%
def findWholeWord(w):
    return re.compile(r'\b({0})\b'.format(w), flags=re.IGNORECASE).search





with open('./transformation/mapping/existing_brand_mapping.json','r') as f:
    existing_brand_mapping = json.loads(f.read())

def predictExistingBrand(predicted_brand, product_name):
    def predictedBrandSearch(predicted_brand, mapping):
        if predicted_brand not in mapping['where_clause']['predicted_brand']:
            return True
        else:
            return False
        

    def brandSearch(product_name, mapping):
        is_match = False
        for brand_name in mapping['where_clause']['include_brand']:
            if findWholeWord(brand_name.upper())(product_name.upper()):
                is_match = True
        return is_match

    def subbrandSearch(product_name, mapping):
        is_match = False
        if len(mapping['where_clause']['include_subbrand']) != 0:
            for subbrand_name in mapping['where_clause']['include_subbrand']:
                if findWholeWord(subbrand_name.upper())(product_name.upper()):
                    is_match = True
        else:
            is_match = True

        return is_match

    def unitSearch(product_name, mapping):
        is_match = False
        if len(mapping['where_clause']['include_unit']) != 0:
            product_name_sub = re.sub(r'\d',' ', product_name)
            for unit in mapping['where_clause']['include_unit']:
                if findWholeWord(unit.upper())(product_name_sub .upper()):
                    is_match = True
        else:
            is_match = True
        return is_match

    def excludeNameSearch(product_name, mapping):
        is_match = False
        if len(mapping['where_clause']['exclude_product_name']) != 0:
            for exclude_pm in mapping['where_clause']['exclude_product_name']:
                if not findWholeWord(exclude_pm.upper())(product_name.upper()):
                    is_match = True
        else:
            is_match = True
        return is_match

    brand = predicted_brand
    is_match = False
    for mapping in existing_brand_mapping:
        if is_match == False:
            if predictedBrandSearch(predicted_brand, mapping):
                if brandSearch(product_name, mapping):
                    if subbrandSearch(product_name, mapping):
                        if unitSearch(product_name, mapping):
                            if excludeNameSearch(product_name, mapping):
                                brand = mapping['brand']
                                is_match = True
    return brand

# %%
        with open('./transformation/mapping/existing_brand_mapping.json','r') as f:
            self.existing_brand_mapping = json.loads(f.read())

# %%
with open('./transformation/mapping/existing_brand_mapping.json','r') as f:
    existing_brand_mapping = json.loads(f.read())
def predictExistingBrand(predicted_brand, product_name):
        def predictedBrandSearch(predicted_brand, mapping):
            if predicted_brand not in mapping['where_clause']['predicted_brand']:
                return True
            else:
                return False
            

        def brandSearch(product_name, mapping):
            is_match = False
            for brand_name in mapping['where_clause']['include_brand']:
                if findWholeWord(brand_name.upper())(product_name.upper()):
                    is_match = True
            return is_match

        def subbrandSearch(product_name, mapping):
            is_match = False
            if len(mapping['where_clause']['include_subbrand']) != 0:
                for subbrand_name in mapping['where_clause']['include_subbrand']:
                    if findWholeWord(subbrand_name.upper())(product_name.upper()):
                        is_match = True
            else:
                is_match = True

            return is_match

        def unitSearch(product_name, mapping):
            is_match = False
            if len(mapping['where_clause']['include_unit']) != 0:
                product_name_sub = re.sub(r'\d',' ', product_name)
                for unit in mapping['where_clause']['include_unit']:
                    if findWholeWord(unit.upper())(product_name_sub .upper()):
                        is_match = True
            else:
                is_match = True
            return is_match

        def excludeNameSearch(product_name, mapping):
            is_match = False
            if len(mapping['where_clause']['exclude_product_name']) != 0:
                for exclude_pm in mapping['where_clause']['exclude_product_name']:
                    if not findWholeWord(exclude_pm.upper())(product_name.upper()):
                        is_match = True
            else:
                is_match = True
            return is_match

        brand = predicted_brand
        is_match = False
        for mapping in existing_brand_mapping:
            if is_match == False:
                if predictedBrandSearch(predicted_brand, mapping):
                    if brandSearch(product_name, mapping):
                        if subbrandSearch(product_name, mapping):
                            if unitSearch(product_name, mapping):
                                if excludeNameSearch(product_name, mapping):
                                    brand = mapping['brand']
                                    is_match = True
        return brand

# %%
import json
import pandas as pd 
import re

df = pd.read_excel('sample_product2.xlsx')
df = df.rename(columns={'brand':'predicted_brand'})
df.loc[:,'predicted_brand'] = ''
df = df[['product_name','predicted_brand']]
df

def lookupBrand(df):
        df['predicted_brand'] = df.apply(lambda x: predictExistingBrand(x['predicted_brand'],x['product_name']),axis=1)
        return df

lookupbrand = lookupBrand(df)
lookupbrand.to_excel('cek.xlsx')

# %%
a = ['a','b','c','d']

for idx, val in enumerate(a):

    print(f"{idx}: {val} ")
# Out:
# 0: a
# 1: b
# 2: c
# 3: d
